# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# with open("./data/RCP3PD_MIDYR_CONC.DAT", 'r') as file:

#     data = file.read()

# # topex = np.fromfile('./data/RCP3PD_MIDYR_CONC.dat')
# df_topex = pd.DataFrame(data=data)

data = pd.read_csv("./data/emission.csv")
data_cmip5= pd.read_csv("./data/cmip5.csv")
data_back= pd.read_csv("./data/BackData.csv")

data1 = pd.read_csv("./data/RCP3PD_MIDYR_CONC.csv")
data2 = pd.read_csv("./data/RCP45_MIDYR_CONC.csv")
data3 = pd.read_csv("./data/RCP6_MIDYR_CONC.csv")
data4 = pd.read_csv("./data/RCP85_MIDYR_CONC.csv")

# %%
plt.plot(data1.loc[135:335,"YEARS"],data1.loc[135:335,"CO2EQ"],label="RCP3")
plt.plot(data1.loc[135:335,"YEARS"],data2.loc[135:335,"CO2EQ"],label="RCP4.5")
plt.plot(data1.loc[135:335,"YEARS"],data3.loc[135:335,"CO2EQ"],label="RCP6")
plt.plot(data1.loc[135:335,"YEARS"],data4.loc[135:335,"CO2EQ"],label="RCP8")
plt.legend()

# %%
plt.plot(data1.loc[135:335,"YEARS"],data1.loc[135:335,"CO2EQ"],label="RCP3")
plt.plot(data1.loc[135:335,"YEARS"],data2.loc[135:335,"CO2EQ"],label="RCP4.5")
plt.plot(data1.loc[135:335,"YEARS"],data3.loc[135:335,"CO2EQ"],label="RCP6")
plt.plot(data1.loc[135:335,"YEARS"],data4.loc[135:335,"CO2EQ"],label="RCP8.5")
plt.legend()

# %%
plt.plot(data.loc[:,"YEARS"],data.loc[:,"RCP3"],label="RCP3")
plt.plot(data.loc[:,"YEARS"],data.loc[:,"RCP4.5"],label="RCP4.5")
plt.plot(data.loc[:,"YEARS"],data.loc[:,"RCP6"],label="RCP6")
plt.plot(data.loc[:,"YEARS"],data.loc[:,"RCP8.5"],label="RCP8.5")
plt.legend()

# %%
plt.plot(data.loc[:,"YEARS"],np.cumsum(data.loc[:,"RCP3"])*.00186*9/5*10,label="RCP3")
plt.plot(data.loc[:,"YEARS"],np.cumsum(data.loc[:,"RCP4.5"])*.00186*9/5*10,label="RCP4.5")
plt.plot(data.loc[:,"YEARS"],np.cumsum(data.loc[:,"RCP6"])*.00186*9/5*10,label="RCP6")
plt.plot(data.loc[:,"YEARS"],np.cumsum(data.loc[:,"RCP8.5"])*.00186*9/5*10,label="RCP8.5")
plt.legend()

# %%
plt.plot(data.loc[:,"YEARS"],np.cumsum(data.loc[:,"RCP3"])*.00186,label="RCP3")
plt.plot(data.loc[:,"YEARS"],np.cumsum(data.loc[:,"RCP4.5"])*.00186,label="RCP4.5")
plt.plot(data.loc[:,"YEARS"],np.cumsum(data.loc[:,"RCP6"])*.00186,label="RCP6")
plt.plot(data.loc[:,"YEARS"],np.cumsum(data.loc[:,"RCP8.5"])*.00186,label="RCP8.5")
plt.legend()

# %%
plt.plot(data_cmip5.loc[0:4,"period"],data_cmip5.loc[0:4,"RCP3"],label="RCP3")
plt.plot(data_cmip5.loc[:,"period"],data_cmip5.loc[:,"RCP4.5"],label="RCP4.5")
# plt.plot(data_cmip5.loc[:,"period"],data_cmip5.loc[:,"RCP6"],label="RCP6")
plt.plot(data_cmip5.loc[:,"period"],data_cmip5.loc[:,"RCP8.5"],label="RCP8.5")
plt.legend()

# %%
plt.plot(data_cmip5.loc[:,"period"],data_cmip5.loc[:,"RCP3"]*9/5,label="RCP3")
plt.plot(data_cmip5.loc[:,"period"],data_cmip5.loc[:,"RCP4.5"]*9/5,label="RCP4.5")
# plt.plot(data_cmip5.loc[:,"period"],data_cmip5.loc[:,"RCP6"]*9/5,label="RCP6")
plt.plot(data_cmip5.loc[:,"period"],data_cmip5.loc[:,"RCP8.5"]*9/5,label="RCP8.5")
plt.legend()

# %%
plt.plot(data_back.loc[:,"YEARS"],data_back.loc[:,"RCP3"],label="RCP3")
plt.plot(data_back.loc[:,"YEARS"],data_back.loc[:,"RCP4.5"],label="RCP4.5")
# plt.plot(data_cmip5.loc[:,"period"],data_cmip5.loc[:,"RCP6"]*9/5,label="RCP6")
plt.plot(data_back.loc[:,"YEARS"],data_back.loc[:,"RCP8"],label="RCP8.5")
plt.title("Temperature Anomaly in Fahrenheit")
plt.legend()

# %%
plt.plot(data_back.loc[:,"YEARS"],data_back.loc[:,"RCP3"]*5/9,label="RCP3")
plt.plot(data_back.loc[:,"YEARS"],data_back.loc[:,"RCP4.5"]*5/9,label="RCP4.5")
# plt.plot(data_cmip5.loc[:,"period"],data_cmip5.loc[:,"RCP6"]*9/5,label="RCP6")
plt.plot(data_back.loc[:,"YEARS"],data_back.loc[:,"RCP8"]*5/9,label="RCP8.5")
plt.title("Temperature Anomaly in Celsius")
plt.legend()
