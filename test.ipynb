# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# with open("./data/RCP3PD_MIDYR_CONC.DAT", 'r') as file:

#     data = file.read()

# # topex = np.fromfile('./data/RCP3PD_MIDYR_CONC.dat')
# df_topex = pd.DataFrame(data=data)

data = pd.read_csv("./data/emission.csv")

data1 = pd.read_csv("./data/RCP3PD_MIDYR_CONC.csv")
data2 = pd.read_csv("./data/RCP45_MIDYR_CONC.csv")
data3 = pd.read_csv("./data/RCP6_MIDYR_CONC.csv")
data4 = pd.read_csv("./data/RCP85_MIDYR_CONC.csv")

# %%
plt.plot(data1.loc[135:335,"YEARS"],data1.loc[135:335,"CO2EQ"],label="RCP3")
plt.plot(data1.loc[135:335,"YEARS"],data2.loc[135:335,"CO2EQ"],label="RCP4.5")
plt.plot(data1.loc[135:335,"YEARS"],data3.loc[135:335,"CO2EQ"],label="RCP6")
plt.plot(data1.loc[135:335,"YEARS"],data4.loc[135:335,"CO2EQ"],label="RCP8")
plt.legend()

# %%
plt.plot(data1.loc[135:335,"YEARS"],data1.loc[135:335,"CO2EQ"]*12/44,label="RCP3")
plt.plot(data1.loc[135:335,"YEARS"],data2.loc[135:335,"CO2EQ"]*12/44,label="RCP4.5")
plt.plot(data1.loc[135:335,"YEARS"],data3.loc[135:335,"CO2EQ"]*12/44,label="RCP6")
plt.plot(data1.loc[135:335,"YEARS"],data4.loc[135:335,"CO2EQ"]*12/44,label="RCP8.5")
plt.legend()

# %%
plt.plot(data.loc[:,"YEARS"],data.loc[:,"RCP3"]*12/44,label="RCP3")
plt.plot(data.loc[:,"YEARS"],data.loc[:,"RCP4.5"]*12/44,label="RCP4.5")
plt.plot(data.loc[:,"YEARS"],data.loc[:,"RCP6"]*12/44,label="RCP6")
plt.plot(data.loc[:,"YEARS"],data.loc[:,"RCP8.5"]*12/44,label="RCP8.5")
plt.legend()
